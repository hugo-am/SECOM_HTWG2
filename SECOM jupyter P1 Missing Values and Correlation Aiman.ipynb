# %%
import pandas as pd
import os

# %%
#Generate an empty list to put column names in
column_list=[]

# %%
#Reading csv file 1
labels=pd.read_csv('secom_labels.data',header=None,sep=' ',names=['status','timestamp'])

# %%
labels
# Out:
#       status            timestamp
# 0         -1  19/07/2008 11:55:00
# 1         -1  19/07/2008 12:32:00
# 2          1  19/07/2008 13:17:00
# 3         -1  19/07/2008 14:43:00
# 4         -1  19/07/2008 15:22:00
# ...      ...                  ...
# 1562      -1  16/10/2008 15:13:00
# 1563      -1  16/10/2008 20:49:00
# 1564      -1  17/10/2008 05:26:00
# 1565      -1  17/10/2008 06:01:00
# 1566      -1  17/10/2008 06:07:00
#
# [1567 rows x 2 columns]

# %%
data=pd.read_csv('secom.data',header=None,sep=' ')

# %%
data
# Out:
#           0        1          2          3       4      5         6       7    \
# 0     3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1     3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2     2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3     2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# 4     3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
# ...       ...      ...        ...        ...     ...    ...       ...     ...
# 1562  2899.41  2464.36  2179.7333  3085.3781  1.4843  100.0   82.2467  0.1248
# 1563  3052.31  2522.55  2198.5667  1124.6595  0.8763  100.0   98.4689  0.1205
# 1564  2978.81  2379.78  2206.3000  1110.4967  0.8236  100.0   99.4122  0.1208
# 1565  2894.92  2532.01  2177.0333  1183.7287  1.5726  100.0   98.7978  0.1213
# 1566  2944.92  2450.76  2195.4444  2914.1792  1.5978  100.0   85.1011  0.1235
#
# ...

# %%
#Naming columns 0-590
for x in range(591):
    column_list.append(f'col_{x}')

# %%
#Remove the first column name as it starts with 0
column_list.remove('col_0')

# %%
#Reading csv file 2
data=pd.read_csv('secom.data',header=None,sep=' ',names=column_list)

# %%
#The secom.names file indicates that both .data files have the same order, therefore we can merge using the index
df=data.merge(labels,left_index=True,right_index=True)

# %%
df.describe().to_clipboard()

# %%
df
# Out:
#         col_1    col_2      col_3      col_4   col_5  col_6     col_7   col_8  \
# 0     3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1     3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2     2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3     2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# 4     3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
# ...       ...      ...        ...        ...     ...    ...       ...     ...
# 1562  2899.41  2464.36  2179.7333  3085.3781  1.4843  100.0   82.2467  0.1248
# 1563  3052.31  2522.55  2198.5667  1124.6595  0.8763  100.0   98.4689  0.1205
# 1564  2978.81  2379.78  2206.3000  1110.4967  0.8236  100.0   99.4122  0.1208
# 1565  2894.92  2532.01  2177.0333  1183.7287  1.5726  100.0   98.7978  0.1213
# 1566  2944.92  2450.76  2195.4444  2914.1792  1.5978  100.0   85.1011  0.1235
#
# ...

# %%
#Duplicated rows in data frame -- none 
df.duplicated().sum()
# Out:
# 0

# %%
#Zero/Low Volatility columns (116 columns) -- checked via excel filter -- "describe function" anything with a 0 sd is fluff.
df.describe().T.to_clipboard()

# %%
df
# Out:
#         col_1    col_2      col_3      col_4   col_5  col_6     col_7   col_8  \
# 0     3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1     3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2     2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3     2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# 4     3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
# ...       ...      ...        ...        ...     ...    ...       ...     ...
# 1562  2899.41  2464.36  2179.7333  3085.3781  1.4843  100.0   82.2467  0.1248
# 1563  3052.31  2522.55  2198.5667  1124.6595  0.8763  100.0   98.4689  0.1205
# 1564  2978.81  2379.78  2206.3000  1110.4967  0.8236  100.0   99.4122  0.1208
# 1565  2894.92  2532.01  2177.0333  1183.7287  1.5726  100.0   98.7978  0.1213
# 1566  2944.92  2450.76  2195.4444  2914.1792  1.5978  100.0   85.1011  0.1235
#
# ...

# %%
df[['col_1']].hist()
# Out:
# array([[<Axes: title={'center': 'col_1'}>]], dtype=object)

# %%
df[['col_14']].hist()
# Out:
# array([[<Axes: title={'center': 'col_14'}>]], dtype=object)

# %%
df[['col_102']].hist()
# Out:
# array([[<Axes: title={'center': 'col_102'}>]], dtype=object)

# %%
#How do you classify the minimum sd requirement -- how much is too little?
df[['col_64']].hist()
# Out:
# array([[<Axes: title={'center': 'col_64'}>]], dtype=object)

# %%
#Eliminating all columns with single digit sd -- they are low volatility -- we get rid of 471 columns, while still maintaining the integrity 
#of valuable information (?)
df[['col_520']].hist()
# Out:
# array([[<Axes: title={'center': 'col_520'}>]], dtype=object)

# %%
#Checking the null values
df.isna().sum().to_clipboard()

# %%
df[['col_295','col_141','col_205','col_161','col_22','col_160','col_24','col_297','col_25','col_298','col_162','col_163']].corr().to_clipboard()

# %%
# Import necessary modules
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation matrix
co_mtx = df[['col_295','col_141','col_205','col_161','col_22','col_160','col_24','col_297','col_25','col_298','col_162','col_163']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_295   col_141   col_205   col_161    col_22   col_160    col_24  \
# col_295  1.000000 -0.003236 -0.014064  0.569384  0.564821  0.993240  0.192170
# col_141 -0.003236  1.000000 -0.002909 -0.002309  0.008139 -0.001842  0.004792
# col_205 -0.014064 -0.002909  1.000000 -0.006697 -0.020330 -0.014309 -0.030505
# col_161  0.569384 -0.002309 -0.006697  1.000000  0.348222  0.548771  0.122487
# col_22   0.564821  0.008139 -0.020330  0.348222  1.000000  0.537685  0.159658
# col_160  0.993240 -0.001842 -0.014309  0.548771  0.537685  1.000000  0.186806
# col_24   0.192170  0.004792 -0.030505  0.122487  0.159658  0.186806  1.000000
# col_297  0.034308 -0.019215  0.008931  0.039834 -0.043329  0.033985  0.131281
# col_25  -0.015008 -0.013057  0.009465  0.037826 -0.179501 -0.018114  0.030027
# col_298 -0.044715 -0.016850 -0.022175 -0.050336  0.173248 -0.039872 -0.003344
# col_162  0.018649 -0.017113  0.012047  0.028141 -0.056155  0.019836  0.131162
# ...

# %%
#Next 10 columns
df[['col_23','col_68','col_501','col_500','col_420','col_512','col_91','col_159','col_226','col_4']].corr().to_clipboard()

# %%
# Import necessary modules
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation matrix
co_mtx = df[['col_23','col_68','col_501','col_500','col_420','col_512','col_91','col_159','col_226','col_4']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#            col_23    col_68   col_501   col_500   col_420   col_512    col_91  \
# col_23   1.000000  0.030159 -0.008786 -0.012575  0.006905  0.045045 -0.002514
# col_68   0.030159  1.000000 -0.025519 -0.015450 -0.002939  0.036086  0.009098
# col_501 -0.008786 -0.025519  1.000000  0.010723  0.027222  0.016424 -0.035717
# col_500 -0.012575 -0.015450  0.010723  1.000000 -0.028106  0.031870  0.007323
# col_420  0.006905 -0.002939  0.027222 -0.028106  1.000000 -0.016856  0.038827
# col_512  0.045045  0.036086  0.016424  0.031870 -0.016856  1.000000  0.009354
# col_91  -0.002514  0.009098 -0.035717  0.007323  0.038827  0.009354  1.000000
# col_159 -0.033275  0.061299  0.006543 -0.077565 -0.048225 -0.064973 -0.022346
# col_226 -0.019350 -0.006261  0.005383 -0.010927 -0.019378  0.026890 -0.018081
# col_4   -0.033202  0.009528  0.017823  0.008542  0.033571 -0.019744 -0.008257
#
#           col_159   col_226     col_4
# col_23  -0.033275 -0.019350 -0.033202
# ...

# %%
df[['col_490','col_469','col_489','col_341','col_140','col_488','col_483','col_296','col_487','col_419']].corr().to_clipboard()

# %%
co_mtx = df[['col_490','col_469','col_489','col_341','col_140','col_488','col_483','col_296','col_487','col_419']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_490   col_469   col_489   col_341   col_140   col_488   col_483  \
# col_490  1.000000  0.010861  0.035072  0.006881 -0.009476  0.036943  0.035193
# col_469  0.010861  1.000000 -0.050443  0.014003  0.053017  0.023551  0.004586
# col_489  0.035072 -0.050443  1.000000 -0.019930 -0.035615  0.007232  0.019559
# col_341  0.006881  0.014003 -0.019930  1.000000  0.000595 -0.019573  0.022936
# col_140 -0.009476  0.053017 -0.035615  0.000595  1.000000  0.067649 -0.030503
# col_488  0.036943  0.023551  0.007232 -0.019573  0.067649  1.000000 -0.029862
# col_483  0.035193  0.004586  0.019559  0.022936 -0.030503 -0.029862  1.000000
# col_296 -0.012148 -0.109683  0.033686 -0.006541 -0.029800 -0.045702 -0.020292
# col_487 -0.028870  0.000423  0.000166 -0.009851 -0.025647  0.057142 -0.033914
# col_419 -0.018482  0.057962 -0.021658 -0.011538  0.019430  0.033960  0.023360
#
#           col_296   col_487   col_419
# col_490 -0.012148 -0.028870 -0.018482
# ...

# %%
df[['col_590','col_522','col_433','col_294','col_364','col_276','col_484','col_485','col_486','col_434']].corr().to_clipboard()

# %%
co_mtx = df[['col_590','col_522','col_433','col_294','col_364','col_276','col_484','col_485','col_486','col_434']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_590   col_522   col_433   col_294   col_364   col_276   col_484  \
# col_590  1.000000  0.033088 -0.016263  0.166397  0.040314  0.051442  0.013753
# col_522  0.033088  1.000000 -0.011688  0.075806  0.028765 -0.005734 -0.000229
# col_433 -0.016263 -0.011688  1.000000 -0.118295 -0.024218 -0.010907  0.002013
# col_294  0.166397  0.075806 -0.118295  1.000000  0.929219 -0.028543  0.027166
# col_364  0.040314  0.028765 -0.024218  0.929219  1.000000  0.023492 -0.027187
# col_276  0.051442 -0.005734 -0.010907 -0.028543  0.023492  1.000000 -0.027884
# col_484  0.013753 -0.000229  0.002013  0.027166 -0.027187 -0.027884  1.000000
# col_485 -0.072000 -0.006000 -0.014380 -0.068136 -0.039828 -0.012851 -0.041936
# col_486 -0.018802 -0.034918 -0.017085  0.089854  0.006920  0.017143 -0.005340
# col_434 -0.014084  0.003971  0.006696 -0.137502 -0.006151  0.020287  0.016783
#
#           col_485   col_486   col_434
# col_590 -0.072000 -0.018802 -0.014084
# ...

# %%
df[['col_224','col_5','col_136','col_52','col_253','col_1','col_2','col_275','col_573','col_582']].corr().to_clipboard()

# %%
co_mtx = df[['col_224','col_5','col_136','col_52','col_253','col_1','col_2','col_275','col_573','col_582']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_224     col_5   col_136    col_52   col_253     col_1     col_2  \
# col_224  1.000000 -0.010304 -0.006029  0.008464 -0.002497 -0.023160 -0.021097
# col_5   -0.010304  1.000000 -0.020544  0.006810 -0.000519 -0.011047 -0.001641
# col_136 -0.006029 -0.020544  1.000000  0.030205  0.002805 -0.070654  0.051530
# col_52   0.008464  0.006810  0.030205  1.000000  0.016819 -0.050945  0.022642
# col_253 -0.002497 -0.000519  0.002805  0.016819  1.000000 -0.004230 -0.003781
# col_1   -0.023160 -0.011047 -0.070654 -0.050945 -0.004230  1.000000 -0.145071
# col_2   -0.021097 -0.001641  0.051530  0.022642 -0.003781 -0.145071  1.000000
# col_275 -0.000186  0.035670  0.064931 -0.005602 -0.004507  0.004803  0.009329
# col_573  0.002504 -0.012027 -0.000157 -0.050662 -0.005791  0.013679  0.001753
# col_582  0.057327  0.088327 -0.008575  0.013118 -0.024034 -0.028380  0.083463
#
#           col_275   col_573   col_582
# col_224 -0.000186  0.002504  0.057327
# ...

# %%
df[['col_432','col_511','col_440','col_414','col_473','col_116','col_138','col_89','col_137','col_251']].corr().to_clipboard()

# %%
co_mtx = df[['col_432','col_511','col_440','col_414','col_473','col_116','col_138','col_89','col_137','col_251']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_432   col_511   col_440   col_414   col_473   col_116   col_138  \
# col_432  1.000000  0.139235 -0.046608  0.010763 -0.082447 -0.016611  0.035267
# col_511  0.139235  1.000000 -0.090295  0.026945 -0.091919 -0.002059  0.034781
# col_440 -0.046608 -0.090295  1.000000  0.021174 -0.010913  0.075145  0.015429
# col_414  0.010763  0.026945  0.021174  1.000000 -0.028856  0.015381 -0.000473
# col_473 -0.082447 -0.091919 -0.010913 -0.028856  1.000000 -0.052033  0.004982
# col_116 -0.016611 -0.002059  0.075145  0.015381 -0.052033  1.000000  0.020387
# col_138  0.035267  0.034781  0.015429 -0.000473  0.004982  0.020387  1.000000
# col_89   0.007205  0.003973  0.017386  0.009415  0.001412  0.116503 -0.018107
# col_137  0.047324  0.013144  0.002027  0.010973  0.011016  0.028051  0.667024
# col_251  0.004341  0.011003  0.020231  0.008882  0.004131  0.020353  0.013194
#
#            col_89   col_137   col_251
# col_432  0.007205  0.047324  0.004341
# ...

# %%
df[['col_152','col_72','col_424','col_439','col_435','col_436','col_437','col_556','col_481','col_431']].corr().to_clipboard()

# %%
co_mtx = df[['col_152','col_72','col_424','col_439','col_435','col_436','col_437','col_556','col_481','col_431']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_152    col_72   col_424   col_439   col_435   col_436   col_437  \
# col_152  1.000000  0.014795  0.204007  0.003536 -0.013988 -0.012405 -0.011908
# col_72   0.014795  1.000000  0.023753  0.083491 -0.017065 -0.013917 -0.012000
# col_424  0.204007  0.023753  1.000000  0.078819  0.035155  0.040601  0.035275
# col_439  0.003536  0.083491  0.078819  1.000000 -0.072521 -0.063282 -0.069987
# col_435 -0.013988 -0.017065  0.035155 -0.072521  1.000000  0.993665  0.992333
# col_436 -0.012405 -0.013917  0.040601 -0.063282  0.993665  1.000000  0.996216
# col_437 -0.011908 -0.012000  0.035275 -0.069987  0.992333  0.996216  1.000000
# col_556 -0.020019 -0.163426 -0.010420 -0.043530  0.030869  0.031000  0.033028
# col_481 -0.029509 -0.490215 -0.025163 -0.126255  0.038486  0.034175  0.036824
# col_431 -0.023683 -0.016178  0.047176 -0.024713  0.948040  0.951673  0.953723
#
#           col_556   col_481   col_431
# col_152 -0.020019 -0.029509 -0.023683
# ...

# %%
df[['col_474','col_426','col_153','col_41','col_497','col_475','col_56','col_575','col_209','col_3']].corr().to_clipboard()

# %%
co_mtx = df[['col_474','col_426','col_153','col_41','col_497','col_475','col_56','col_575','col_209','col_3']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_474   col_426   col_153    col_41   col_497   col_475    col_56  \
# col_474  1.000000 -0.032562 -0.024215  0.024092 -0.007999  0.786253  0.064747
# col_426 -0.032562  1.000000  0.975092  0.008288  0.044927 -0.026227  0.002022
# col_153 -0.024215  0.975092  1.000000  0.011689  0.040632 -0.017779  0.002610
# col_41   0.024092  0.008288  0.011689  1.000000  0.036737  0.021824 -0.038469
# col_497 -0.007999  0.044927  0.040632  0.036737  1.000000  0.024487  0.020133
# col_475  0.786253 -0.026227 -0.017779  0.021824  0.024487  1.000000  0.089668
# col_56   0.064747  0.002022  0.002610 -0.038469  0.020133  0.089668  1.000000
# col_575 -0.018831 -0.001158 -0.005927 -0.012104  0.008940 -0.006180  0.015071
# col_209 -0.065849  0.038255  0.035394 -0.067070 -0.020441 -0.066298 -0.001776
# col_3   -0.033433  0.028668  0.018249 -0.015107  0.049409 -0.053098 -0.008115
#
#           col_575   col_209     col_3
# col_474 -0.018831 -0.065849 -0.033433
# ...

# %%
df[['col_273','col_272','col_491','col_73','col_413','col_149','col_562','col_391','col_525','col_189']].corr().to_clipboard()

# %%
co_mtx = df[['col_273','col_272','col_491','col_73','col_413','col_149','col_562','col_391','col_525','col_189']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_273   col_272   col_491    col_73   col_413   col_149   col_562  \
# col_273  1.000000  0.706269  0.002892  0.051987  0.049845 -0.019136 -0.073968
# col_272  0.706269  1.000000 -0.008080  0.010073  0.037784 -0.021178 -0.053900
# col_491  0.002892 -0.008080  1.000000 -0.029978  0.015948 -0.040628  0.004777
# col_73   0.051987  0.010073 -0.029978  1.000000  0.040914 -0.013097 -0.040426
# col_413  0.049845  0.037784  0.015948  0.040914  1.000000  0.002115  0.044611
# col_149 -0.019136 -0.021178 -0.040628 -0.013097  0.002115  1.000000 -0.013090
# col_562 -0.073968 -0.053900  0.004777 -0.040426  0.044611 -0.013090  1.000000
# col_391 -0.029573 -0.005607 -0.004383 -0.005337 -0.021001 -0.005096  0.058722
# col_525 -0.030320 -0.006920 -0.006276 -0.007460 -0.021694 -0.005876  0.052839
# col_189 -0.027947 -0.012487 -0.011360  0.026863 -0.004579 -0.030811  0.000547
#
#           col_391   col_525   col_189
# col_273 -0.029573 -0.030320 -0.027947
# ...

# %%
df[['col_577','col_362','col_347','col_16','col_389','col_204','col_208','col_571','col_346','col_74']].corr().to_clipboard()

# %%
co_mtx = df[['col_577','col_362','col_347','col_16','col_389','col_204','col_208','col_571','col_346','col_74']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_577   col_362   col_347    col_16   col_389   col_204   col_208  \
# col_577  1.000000  0.010288  0.180327 -0.023511  0.012834  0.004589  0.010371
# col_362  0.010288  1.000000 -0.010511  0.020748  0.056451  0.015113  0.004525
# col_347  0.180327 -0.010511  1.000000  0.052634 -0.042537  0.526163  0.611711
# col_16  -0.023511  0.020748  0.052634  1.000000 -0.000750  0.089080  0.051771
# col_389  0.012834  0.056451 -0.042537 -0.000750  1.000000 -0.036950 -0.034692
# col_204  0.004589  0.015113  0.526163  0.089080 -0.036950  1.000000  0.860644
# col_208  0.010371  0.004525  0.611711  0.051771 -0.034692  0.860644  1.000000
# col_571 -0.360498 -0.001907 -0.448093  0.011929 -0.014040  0.000939  0.005549
# col_346  0.168220 -0.016313  0.982621  0.021445 -0.050996  0.517754  0.666248
# col_74   0.213015 -0.001249  0.843282 -0.005006 -0.019660  0.259340  0.345246
#
#           col_571   col_346    col_74
# col_577 -0.360498  0.168220  0.213015
# ...

# %%
df[['col_67','col_47','col_139','col_578','col_461','col_203','col_477','col_197','col_520','col_200']].corr().to_clipboard()

# %%
co_mtx = df[['col_67','col_47','col_139','col_578','col_461','col_203','col_477','col_197','col_520','col_200']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#            col_67    col_47   col_139   col_578   col_461   col_203   col_477  \
# col_67   1.000000  0.824381 -0.060973  0.015888 -0.126680 -0.095941  0.029212
# col_47   0.824381  1.000000 -0.039959  0.016526 -0.126097  0.113189  0.022976
# col_139 -0.060973 -0.039959  1.000000 -0.034499  0.015066 -0.033832 -0.028286
# col_578  0.015888  0.016526 -0.034499  1.000000  0.078922  0.032113 -0.015497
# col_461 -0.126680 -0.126097  0.015066  0.078922  1.000000 -0.009743 -0.083863
# col_203 -0.095941  0.113189 -0.033832  0.032113 -0.009743  1.000000  0.191062
# col_477  0.029212  0.022976 -0.028286 -0.015497 -0.083863  0.191062  1.000000
# col_197  0.037568  0.063492 -0.044785  0.044666 -0.005705  0.698696  0.402887
# col_520 -0.097073 -0.032626  0.055127  0.001803  0.018777 -0.013105  0.026736
# col_200 -0.011437 -0.011140 -0.044839  0.052354 -0.029277  0.651989  0.435279
#
#           col_197   col_520   col_200
# col_67   0.037568 -0.097073 -0.011437
# ...

# %%
df[['col_247','col_472','col_478','col_570','col_198','col_429','col_517','col_206']].corr().to_clipboard()

# %%
co_mtx = df[['col_247','col_472','col_478','col_570','col_198','col_429','col_517','col_206']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_247   col_472   col_478   col_570   col_198   col_429   col_517  \
# col_247  1.000000 -0.020721 -0.010357 -0.003356 -0.040959 -0.013284  0.991890
# col_472 -0.020721  1.000000  0.638657 -0.007369  0.686615 -0.026356 -0.027673
# col_478 -0.010357  0.638657  1.000000 -0.015629  0.848324 -0.010547 -0.010517
# col_570 -0.003356 -0.007369 -0.015629  1.000000 -0.015139  0.108374  0.004250
# col_198 -0.040959  0.686615  0.848324 -0.015139  1.000000 -0.020431 -0.035123
# col_429 -0.013284 -0.026356 -0.010547  0.108374 -0.020431  1.000000 -0.007935
# col_517  0.991890 -0.027673 -0.010517  0.004250 -0.035123 -0.007935  1.000000
# col_206 -0.012493  0.629578  0.986622 -0.018194  0.841704 -0.011299 -0.011940
#
#           col_206
# col_247 -0.012493
# col_472  0.629578
# col_478  0.986622
# col_570 -0.018194
# col_198  0.841704
# col_429 -0.011299
# col_517 -0.011940
# col_206  1.000000

# %%
#last 10 columns (originally, only 8 of the last columns remained. This will give a good comparison in terms of the standard deviation
#(lost two digit sd vs highest)

df[['col_247','col_472','col_478','col_570','col_198','col_429','col_517','col_206','col_67','col_47']].corr().to_clipboard()

# %%
co_mtx = df[['col_247','col_472','col_478','col_570','col_198','col_429','col_517','col_206','col_67','col_47']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#           col_247   col_472   col_478   col_570   col_198   col_429   col_517  \
# col_247  1.000000 -0.020721 -0.010357 -0.003356 -0.040959 -0.013284  0.991890
# col_472 -0.020721  1.000000  0.638657 -0.007369  0.686615 -0.026356 -0.027673
# col_478 -0.010357  0.638657  1.000000 -0.015629  0.848324 -0.010547 -0.010517
# col_570 -0.003356 -0.007369 -0.015629  1.000000 -0.015139  0.108374  0.004250
# col_198 -0.040959  0.686615  0.848324 -0.015139  1.000000 -0.020431 -0.035123
# col_429 -0.013284 -0.026356 -0.010547  0.108374 -0.020431  1.000000 -0.007935
# col_517  0.991890 -0.027673 -0.010517  0.004250 -0.035123 -0.007935  1.000000
# col_206 -0.012493  0.629578  0.986622 -0.018194  0.841704 -0.011299 -0.011940
# col_67  -0.030321 -0.116940  0.034989 -0.029060  0.106998 -0.004273 -0.027729
# col_47  -0.010590 -0.053780  0.021714 -0.013172  0.104940 -0.009505 -0.007989
#
#           col_206    col_67    col_47
# col_247 -0.012493 -0.030321 -0.010590
# ...

# %%
co_mtx = df[['col_247','col_472','col_478','col_570','col_198','col_429','col_517','col_206','col_67','col_47']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, annot=True, fmt='.2f', cmap='YlGn')

# Display heatmap
plt.show()
# Out:
#           col_247   col_472   col_478   col_570   col_198   col_429   col_517  \
# col_247  1.000000 -0.020721 -0.010357 -0.003356 -0.040959 -0.013284  0.991890
# col_472 -0.020721  1.000000  0.638657 -0.007369  0.686615 -0.026356 -0.027673
# col_478 -0.010357  0.638657  1.000000 -0.015629  0.848324 -0.010547 -0.010517
# col_570 -0.003356 -0.007369 -0.015629  1.000000 -0.015139  0.108374  0.004250
# col_198 -0.040959  0.686615  0.848324 -0.015139  1.000000 -0.020431 -0.035123
# col_429 -0.013284 -0.026356 -0.010547  0.108374 -0.020431  1.000000 -0.007935
# col_517  0.991890 -0.027673 -0.010517  0.004250 -0.035123 -0.007935  1.000000
# col_206 -0.012493  0.629578  0.986622 -0.018194  0.841704 -0.011299 -0.011940
# col_67  -0.030321 -0.116940  0.034989 -0.029060  0.106998 -0.004273 -0.027729
# col_47  -0.010590 -0.053780  0.021714 -0.013172  0.104940 -0.009505 -0.007989
#
#           col_206    col_67    col_47
# col_247 -0.012493 -0.030321 -0.010590
# ...

# %%
#Outlier detection
df[['col_295']].hist()
# Out:
# array([[<Axes: title={'center': 'col_295'}>]], dtype=object)

# %%
column_mean_outlier = df['col_295'].mean()

# %%
column_std_outlier = df['col_295'].std()

# %%
col_mnstd = column_mean_outlier+(column_std_outlier*1)

# %%
df['col_295'].loc[(df['col_295'] > col_mnstd)|(df['col_295'] < col_mnstd)]
# Out:
# 0       418.1363
# 1       233.9865
# 2       251.4536
# 3       415.5048
# 4       319.1252
#           ...
# 1562    523.1165
# 1563    232.9741
# 1564    543.1264
# 1565    713.8171
# 1566    346.0101
# Name: col_295, Length: 1565, dtype: float64

# %%
new_variable = df['col_295'].loc[(df['col_295'] > col_mnstd)|(df['col_295'] < col_mnstd)].copy()

# %%
df
# Out:
#         col_1    col_2      col_3      col_4   col_5  col_6     col_7   col_8  \
# 0     3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1     3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2     2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3     2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# 4     3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
# ...       ...      ...        ...        ...     ...    ...       ...     ...
# 1562  2899.41  2464.36  2179.7333  3085.3781  1.4843  100.0   82.2467  0.1248
# 1563  3052.31  2522.55  2198.5667  1124.6595  0.8763  100.0   98.4689  0.1205
# 1564  2978.81  2379.78  2206.3000  1110.4967  0.8236  100.0   99.4122  0.1208
# 1565  2894.92  2532.01  2177.0333  1183.7287  1.5726  100.0   98.7978  0.1213
# 1566  2944.92  2450.76  2195.4444  2914.1792  1.5978  100.0   85.1011  0.1235
#
# ...

# %%
# Import necessary modules
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation matrix
co_mtx = df[['col_295','col_141','col_205','col_161','col_22','col_160','col_24','col_297','col_25','col_298','col_162','col_163']].corr()

# Print correlation matrix
print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, annot=True, fmt='.2f', cmap='YlGn')

# Display heatmap
plt.show()
# Out:
#           col_295   col_141   col_205   col_161    col_22   col_160    col_24  \
# col_295  1.000000 -0.003236 -0.014064  0.569384  0.564821  0.993240  0.192170
# col_141 -0.003236  1.000000 -0.002909 -0.002309  0.008139 -0.001842  0.004792
# col_205 -0.014064 -0.002909  1.000000 -0.006697 -0.020330 -0.014309 -0.030505
# col_161  0.569384 -0.002309 -0.006697  1.000000  0.348222  0.548771  0.122487
# col_22   0.564821  0.008139 -0.020330  0.348222  1.000000  0.537685  0.159658
# col_160  0.993240 -0.001842 -0.014309  0.548771  0.537685  1.000000  0.186806
# col_24   0.192170  0.004792 -0.030505  0.122487  0.159658  0.186806  1.000000
# col_297  0.034308 -0.019215  0.008931  0.039834 -0.043329  0.033985  0.131281
# col_25  -0.015008 -0.013057  0.009465  0.037826 -0.179501 -0.018114  0.030027
# col_298 -0.044715 -0.016850 -0.022175 -0.050336  0.173248 -0.039872 -0.003344
# col_162  0.018649 -0.017113  0.012047  0.028141 -0.056155  0.019836  0.131162
# ...

# %%
df['status']=df['status'].replace(-1,0)

# %%
df
# Out:
#         col_1    col_2      col_3      col_4   col_5  col_6     col_7   col_8  \
# 0     3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1     3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2     2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3     2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# 4     3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
# ...       ...      ...        ...        ...     ...    ...       ...     ...
# 1562  2899.41  2464.36  2179.7333  3085.3781  1.4843  100.0   82.2467  0.1248
# 1563  3052.31  2522.55  2198.5667  1124.6595  0.8763  100.0   98.4689  0.1205
# 1564  2978.81  2379.78  2206.3000  1110.4967  0.8236  100.0   99.4122  0.1208
# 1565  2894.92  2532.01  2177.0333  1183.7287  1.5726  100.0   98.7978  0.1213
# 1566  2944.92  2450.76  2195.4444  2914.1792  1.5978  100.0   85.1011  0.1235
#
# ...

# %%
tgt=['status']
